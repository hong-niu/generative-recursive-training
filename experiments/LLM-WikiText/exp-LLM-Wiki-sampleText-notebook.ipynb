# %% [markdown]
# ## Experiment: LLM (GPT2) - WikiText
# - Sample text from saved models

# %% [markdown]
# ## For publication

# %%
prompt = "The history of science"

# !python exp-LLM-Wiki-sampleText.py \
  --run-dir runs/alpha=0.5_llm_recursive_mix \
  --iters-str "1-5,10,20,40-50" \
  --prompt "$prompt" \
  --n-samples 5 \
  --max-new-tokens 100 \
  --temperature 0.9 \
  --top-p 0.95 \
  --repetition-penalty 1.05 \
  --fp16 \
  --trim-prompt --save --single-file \
  --seed 123
